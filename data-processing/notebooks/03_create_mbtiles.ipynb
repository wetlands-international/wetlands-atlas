# %% [markdown]
# # Create MBTiles from GeoJSON
#
# In this notebook, we will convert GeoJSON files into MBTiles format using the `tippecanoe` tool. This is useful for creating vector tiles that can be used in web mapping applications.
#
# ## Table of Contents
# ### [Locations Table](#locations)
# - **[Country Boundaries (OSM)](#country-boundaries)**
# - **[HydroBASINS](#hydro)**
#
# ## Setup
#
# ### Library import

# %%
from pathlib import Path

from processing.helpers.mbtiles_converter import convert_geojson_to_mbtiles

# %% [markdown]
# ### Variables

# %%
DATA_PATH = Path("../data/processed")

# %% [markdown]
# <a id='locations'></a>
# ## Locations

# %% [markdown]
# <a id='country-boundaries'></a>
# ### Country Boundaries (OSM)
#
# **Convert to `MBTiles`**

# %%
source_path = DATA_PATH / "countries_sahel.geojson"
output_path = DATA_PATH / "countries_sahel.mbtiles"

convert_geojson_to_mbtiles(source_path, output_path)
# Out:
# Converting GeoJSON to mbtiles...
# Source: ../data/processed/countries_sahel.geojson
# Output: ../data/processed/countries_sahel.mbtiles
# Successfully created mbtiles file: ../data/processed/countries_sahel.mbtiles
# PosixPath('../data/processed/countries_sahel.mbtiles')

# %% [markdown]
# <a id='hydro'></a>
# ### HydroBASINS
#
# **Convert to `MBTiles`**

# %%
source_path = DATA_PATH / "hydrobasins_sahel.geojson"
output_path = DATA_PATH / "hydrobasins_sahel.mbtiles"

convert_geojson_to_mbtiles(source_path, output_path)
# Out:
# Converting GeoJSON to mbtiles...
# Source: ../data/processed/hydrobasins_sahel.geojson
# Output: ../data/processed/hydrobasins_sahel.mbtiles
# Successfully created mbtiles file: ../data/processed/hydrobasins_sahel.mbtiles
# PosixPath('../data/processed/hydrobasins_sahel.mbtiles')
