# %% [markdown]
# # Raster Data Download and Preprocessing
#
# In this notebook, we will download the raster data for wetlands and preprocess it to create an Cloud Optimized GeoTiff (COG). The data will be stored in a GCS bucket and can be used for further analysis or visualization.
#
# ## Table of Contents
# ### [Data Download](#data-download)
# - **[Wetlands](#wetlands)**
#
# ## Setup
#
# ### Library import

# %%
from pathlib import Path

from processing.pipelines.wetlands import download_wetlands

# %% [markdown]
# <a id='wetlands'></a>
# ### Wetlands ([source](https://drive.google.com/file/d/1VQGC-iV5Rhd1tC-ScBT2ujq6vT5U5yXH/view?usp=drive_link))

# %% [markdown]
# **Download data**

# %%
directory = Path("../data/raw/")
file_name = "IUCN_Classified_Sahel_2019-2023_Dev-V2_Min_ROI.tif"
file_id = "1VQGC-iV5Rhd1tC-ScBT2ujq6vT5U5yXH"
download_wetlands(raw_data_dir=directory, file_name=file_name, file_id=file_id)
# Out:
# 📥 Downloading wetlands data...
# ✅ Downloaded wetlands data to ../data/raw/IUCN_Classified_Sahel_2019-2023_Dev-V2_Min_ROI.tif
